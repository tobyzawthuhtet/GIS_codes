# %%
import matplotlib.pyplot as plt
import os
import glob as glob
import gdal
import numpy as np
import earthpy as et
import earthpy.plot as ep
from matplotlib.colors import ListedColormap
from matplotlib.colors import LinearSegmentedColormap

# %%
os.getcwd()
# Out:
# 'C:\\Users\\hp'

# %%
os.chdir('D:\Village Link\Ko Sai Project\Raster\Hopong\images')

# %%
data = glob.glob('Grow*.tif')


for i in data:
    #print("found data =",i)
    img= gdal.Open(i)
    band = img.ReadAsArray()
    band = band[1500:6838]
   
    date=('Date {0} - {1} -{2}'.format(i[13:17], i[17:19], i[19:21]))
    plt.figure(figsize=(10,10))    
    colors =["black","green","#00A300","#00D100","#00FF00","#2EFF2E" ,"#5CFF5C","#8AFF8A","yellow","black"]
    plt.imshow(band, cmap=ListedColormap(colors))
    plt.tick_params(left = False, right = False , labelleft = False ,
                labelbottom = False, bottom = False)
    plt.colorbar()
    plt.title(date)
    plt.savefig('D:\Village Link\Ko Sai Project\Raster\Hopong\images\png\clplot'+ date +'.png', bbox_inches="tight",dpi=300,transparent=True)
# Out:
# <ipython-input-18-11e78a46e4d6>:11: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure(figsize=(10,10))

# %%
data = glob.glob('Grow*.tif')

band = band[1200:6838]
plt.imshow(band)

# %%
plt.figure(figsize=(5, 10))
#colors =["green", "orange", 
 ##       "gold", "blue", "k", 
     #  "#550011", "purple",
     #  "red"]


colors =["black","green","#00A300","#00D100","#00FF00","#2EFF2E" ,"#5CFF5C","#8AFF8A","red"]

plt.imshow(band, cmap=ListedColormap(colors))
#plt.imshow(band,cmap=LinearSegmentedColormap('testCmap',segmentdata=cdict,N=256))
plt.colorbar()
plt.title(i)
plt.tick_params(left = False, right = False , labelleft = False ,
                labelbottom = False, bottom = False)
#plt.savefig('D:\Village Link\Ko Sai Project\Raster\Hopong\images\png\plot.png',dpi=1000,tranparent=True,
 #          bbox_inches="tight")

# %%
for i in data:
    date=('Date {0} - {1} -{2}'.format(i[13:17], i[17:19], i[19:21]))
    #print('Date {0} - {1} -{2}'.format(i[13:17], i[17:19], i[19:21]))
    print(date)
# Out:
# Date 2020 - 02 -05
# Date 2020 - 02 -11
# Date 2020 - 02 -17
# Date 2020 - 02 -23
# Date 2020 - 02 -29
# Date 2020 - 03 -06
# Date 2020 - 03 -12
# Date 2020 - 03 -18
# Date 2020 - 03 -24
# Date 2020 - 03 -30
# Date 2020 - 04 -05
# Date 2020 - 04 -11
# Date 2020 - 04 -17
# Date 2020 - 04 -23
# Date 2020 - 04 -29
# Date 2020 - 05 -05
# Date 2020 - 05 -11
# Date 2020 - 05 -17
# Date 2020 - 05 -23
# Date 2020 - 05 -29
# Date 2020 - 06 -04
# Date 2020 - 06 -10
# Date 2020 - 06 -16
# Date 2020 - 06 -22
# Date 2020 - 06 -28
# Date 2020 - 07 -04
# Date 2020 - 07 -10
# Date 2020 - 07 -16
# Date 2020 - 07 -22
# Date 2020 - 07 -28
# Date 2020 - 08 -03
# Date 2020 - 08 -09
# Date 2020 - 08 -15
# Date 2020 - 08 -21
# Date 2020 - 08 -27
# Date 2020 - 09 -02
# Date 2020 - 09 -08
# Date 2020 - 09 -14
# Date 2020 - 09 -20
# Date 2020 - 09 -26
# Date 2020 - 10 -02
# Date 2020 - 10 -08
# Date 2020 - 10 -14
# Date 2020 - 10 -20
# Date 2020 - 10 -26
# Date 2020 - 11 -01
# Date 2020 - 11 -07
# ...

# %%
os.chdir('D:\Village Link\Ko Sai Project\Raster\Hopong\MoonSoon Corn( Jun-Nov )\GIF')

# %%
os.chdir('D:\Village Link\Ko Sai Project\Raster\Hopong\images')

# %%
jpg= glob.glob("crop_mapping*.jpg")
for i in jpg:
    print(i)
# Out:
# crop_mapping_2020_05_05.jpg
# crop_mapping_2020_05_11.jpg
# crop_mapping_2020_05_17.jpg
# crop_mapping_2020_05_23.jpg
# crop_mapping_2020_05_29.jpg
# crop_mapping_2020_06_04.jpg
# crop_mapping_2020_06_10.jpg
# crop_mapping_2020_06_16.jpg
# crop_mapping_2020_06_22.jpg
# crop_mapping_2020_06_28.jpg
# crop_mapping_2020_07_04.jpg
# crop_mapping_2020_07_10.jpg
# crop_mapping_2020_07_16.jpg
# crop_mapping_2020_07_22.jpg
# crop_mapping_2020_07_28.jpg
# crop_mapping_2020_08_03.jpg
# crop_mapping_2020_08_09.jpg
# crop_mapping_2020_08_15.jpg
# crop_mapping_2020_08_21.jpg
# crop_mapping_2020_08_27.jpg
# crop_mapping_2020_09_02.jpg
# crop_mapping_2020_09_08.jpg
# crop_mapping_2020_09_14.jpg
# crop_mapping_2020_09_20.jpg
# crop_mapping_2020_09_26.jpg
# crop_mapping_2020_10_02.jpg
# crop_mapping_2020_10_08.jpg
# crop_mapping_2020_10_14.jpg
# crop_mapping_2020_10_20.jpg
# crop_mapping_2020_10_26.jpg
# crop_mapping_2020_11_01.jpg
# crop_mapping_2020_11_07.jpg
# crop_mapping_2020_11_13.jpg
# ...

# %%
import imageio
from pathlib import Path

# %%
image_path = Path('D:\Village Link\Ko Sai Project\Raster\Hopong\images\png')
images = list(image_path.glob('*.png'))
image_list = []
for file_name in images:
    image_list.append(imageio.imread(file_name))

# %%
imageio.mimwrite(r'D:\Village Link\Ko Sai Project\Raster\Hopong\images\png\final_animation.gif',image_list)

# %%
image_path = Path('D:\Village Link\Ko Sai Project\Raster\Hopong\images')
images = list(image_path.glob('crop_mapping*.jpg'))
image_list = []
for file_name in images:
    image_list.append(imageio.imread(file_name))

# %%
imageio.mimwrite(r'D:\Village Link\Ko Sai Project\Raster\Hopong\images\final_animation_crop.gif',image_list)

# %%
os.getcwd()
# Out:
# 'D:\\Village Link\\Ko Sai Project\\Raster\\Hopong\\MoonSoon Corn( Jun-Nov )\\GIF'

# %%
os.chdir(r'D:\Village Link\SARVision_corndata\Shan South\vector\proj')

# %%
vec = glob.glob('*.shp')
for i in vec:
    print(i)
# Out:
# Hseni.shp
# Hsipaw.shp
# Kalaw.shp
# Kutkai.shp
# Kyaukme.shp
# Kyethi.shp
# Laihka.shp
# Langkho.shp
# Lashio.shp
# Lawksawk.shp
# Loilen.shp
# Mabein.shp
# Manton.shp
# Mawkmai.shp
# Mongkaing.shp
# Mongmit.shp
# Mongnai.shp
# Mongpan.shp
# Mongyai.shp
# Namhkan.shp
# Namhsan.shp
# Namtu.shp
# Nansang.shp
# Nawnghkio.shp
# Nyaungshwe.shp
# Pekon.shp
# Pindaya.shp
# Pinlaung.shp
# shan_states.shp
# Taunggyi.shp
# Ywangan.shp

# %%
for i in vec:
    vector = i[:-4]
    print(vector)
    os.mkdir('D:\Village Link\SARVision_corndata\shan states raster\ ' + str(vector))
# Out:
# Hseni
# Hsipaw
# Kalaw
# Kutkai
# Kyaukme
# Kyethi
# Laihka
# Langkho
# Lashio
# Lawksawk
# Loilen
# Mabein
# Manton
# Mawkmai
# Mongkaing
# Mongmit
# Mongnai
# Mongpan
# Mongyai
# Namhkan
# Namhsan
# Namtu
# Nansang
# Nawnghkio
# Nyaungshwe
# Pekon
# Pindaya
# Pinlaung
# shan_states
# Taunggyi
# Ywangan

# %%
import glob
from PIL import Image

# filepaths
#fp_in = "/path/to/image_*.png"
#fp_out = "/path/to/image.gif"

fp_in = "D:\Village Link\Ko Sai Project\Raster\Hopong\images\crop_mapping_*.jpg"
fp_out = "D:\Village Link\Ko Sai Project\Raster\Hopong\images\image2.gif"

# https://pillow.readthedocs.io/en/stable/handbook/image-file-formats.html#gif
img, *imgs = [Image.open(f) for f in sorted(glob.glob(fp_in))]
img.save(fp=fp_out, format='GIF', append_images=imgs,
         save_all=True, duration=400, loop=0)
